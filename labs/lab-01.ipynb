# %%
import os
from dotenv import load_dotenv
from openai import AsyncOpenAI
from agents.models.openai_chatcompletions import OpenAIChatCompletionsModel

load_dotenv()
# Out:
# True

# %%
base_url = os.getenv("BASE_URL", "http://localhost:11434/v1")
model_key = os.getenv("MODEL_KEY", "ollama")
model_name = os.getenv("MODEL_NAME", "minimax-m2.5:cloud")

# %%
local_model = OpenAIChatCompletionsModel(
    model="minimax-m2.5:cloud",
    openai_client= AsyncOpenAI(
        api_key=model_key,
        base_url=base_url
    )
)

# %%
from agents import Agent, Runner

agent = Agent(
    model=local_model,
    name="Greeter",
    instructions="You are a friendly assistant. Be concise.",
)

# In Jupyter, use await directly (no asyncio.run needed)
result = await Runner.run(agent, "What is the capital of Pakistan?")
print(result.final_output)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# The capital of Pakistan is **Islamabad**. It became the capital in 1967, replacing Karachi.
# OPENAI_API_KEY is not set, skipping trace export

# %%
from agents import Agent, Runner

agent = Agent(
    model=local_model,
    name="Analyst",
    instructions="You analyze topics briefly."
)

result = await Runner.run(agent, "Why is Python popular for AI?")

# The key properties of RunResult:
print("=" * 50)
print(f"Final Output:  {result.final_output[:100]}...")   # The text response
print(f"Last Agent:    {result.last_agent.name}")          # Which agent finished
print(f"New Items:     {len(result.new_items)}")           # Items generated during run
print(f"Raw Responses: {len(result.raw_responses)}")       # Raw LLM responses
print("=" * 50)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# ==================================================
# Final Output:  **Python dominates AI because it’s easy to use, has a huge ecosystem, and lets researchers prototype...
# Last Agent:    Analyst
# New Items:     1
# Raw Responses: 1
# ==================================================
# OPENAI_API_KEY is not set, skipping trace export

# %%
from agents import Agent, Runner

agent = Agent(
    model=local_model,
    name="Tutor",
    instructions="You are a Python tutor. Be concise. Remember context from previous messages."
)

# Turn 1
result = await Runner.run(agent, "What is a list in Python?")
print(f"Turn 1: {result.final_output}\n")

# Turn 2 — carry conversation history forward
new_input = result.to_input_list() + [{"role": "user", "content": "How do I sort one?"}]
result = await Runner.run(agent, new_input)
print(f"Turn 2: {result.final_output}\n")

# Turn 3
new_input = result.to_input_list() + [{"role": "user", "content": "What about reverse sort?"}]
result = await Runner.run(agent, new_input)
print(f"Turn 3: {result.final_output}")
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# Turn 1: # List in Python
#
# A **list** is an ordered, mutable collection of items. It's one of the most versatile data structures in Python.
#
# ## Key characteristics
#
# - **Ordered** — items have a specific order and can be accessed by index
# - **Mutable** — you can add, remove, or modify items
# - **Heterogeneous** — can hold items of different types
# - **Dynamic** — can grow or shrink as needed
#
# ## Examples
#
# ```python
# # Create a list
# fruits = ["apple", "banana", "cherry"]
#
# # Access items by index (0-based)
# print(fruits[0])  # apple
#
# # Modify an item
# fruits[1] = "orange"
#
# # Add items
# fruits.append("grape")
# fruits.insert(0, "mango")
#
# # Remove items
# fruits.remove("cherry")
# popped = fruits.pop()
#
# # Other operations
# print(len(fruits))  # length
# print("apple" in fruits)  # membership check
# ```
#
# Lists are denoted by square brackets `[]` and items are separated by commas.
# OPENAI_API_KEY is not set, skipping trace export
# Turn 2: # Sorting a List in Python
#
# There are two main ways to sort a list:
#
# ## 1. `.sort()` method (in-place)
#
# Modifies the list directly, returns `None`.
#
# ```python
# numbers = [3, 1, 4, 1, 5, 9, 2, 6]
# numbers.sort()
# print(numbers)  # [1, 1, 2, 3, 4, 5, 6, 9]
#
# # Reverse sort
# numbers.sort(reverse=True)
# print(numbers)  # [9, 6, 5, 4, 3, 2, 1, 1]
# ```
#
# ## 2. `sorted()` function (returns new list)
#
# Returns a new sorted list, original remains unchanged.
#
# ```python
# numbers = [3, 1, 4, 1, 5, 9, 2, 6]
# sorted_numbers = sorted(numbers)
# print(numbers)          # [3, 1, 4, 1, 5, 9, 2, 6] (unchanged)
# print(sorted_numbers)  # [1, 1, 2, 3, 4, 5, 6, 9]
# ```
#
# ## Sorting with custom key
#
# ```python
# words = ["apple", "pie", "banana"]
# words.sort(key=len)  # sort by length
# print(words)  # ["pie", "apple", "banana"]
# ```
#
# **When to use which:**
# - Use `.sort()` if you don't need to keep the original list
# - Use `sorted()` if you need to preserve the original list
#
# Turn 3: # Reverse Sort
#
# Two ways to sort in descending order:
#
# ## Using `.sort()`
#
# ```python
# numbers = [3, 1, 4, 1, 5]
# numbers.sort(reverse=True)
# print(numbers)  # [5, 4, 3, 1, 1]
# ```
#
# ## Using `sorted()`
#
# ```python
# numbers = [3, 1, 4, 1, 5]
# desc = sorted(numbers, reverse=True)
# print(desc)  # [5, 4, 3, 1, 1]
# ```
#
# ## Reverse without sorting
#
# Simply reverse the order of an existing list:
#
# ```python
# numbers = [1, 2, 3, 4, 5]
# numbers.reverse()
# print(numbers)  # [5, 4, 3, 2, 1]
#
# # Or using slicing
# print(numbers[::-1])  # [5, 4, 3, 2, 1]
# ```
# OPENAI_API_KEY is not set, skipping trace export

# %%
from agents import Agent, Runner

agent = Agent(
    model=local_model,
    name="Streamer",
    instructions="Explain briefly."
)

# Streaming — see tokens as they arrive
result = Runner.run_streamed(agent, "What is machine learning in 2 sentences?")

async for event in result.stream_events():
    if event.type == "raw_response_event" and hasattr(event.data, 'delta'):
        print(event.data.delta, end="", flush=True)

print(f"\n\n--- Final: {result.final_output}")
# Out:
# The user wants a brief explanation of machine learning in just 2 sentences.
#
#
# Machine learning is a subset of artificial intelligence that enables computers to learn from data and improve their performance on tasks without being explicitly programmed. It involves algorithms that identify patterns in data and make predictions or decisions based on those patterns.
#
# --- Final:
#
# Machine learning is a subset of artificial intelligence that enables computers to learn from data and improve their performance on tasks without being explicitly programmed. It involves algorithms that identify patterns in data and make predictions or decisions based on those patterns.
# OPENAI_API_KEY is not set, skipping trace export
